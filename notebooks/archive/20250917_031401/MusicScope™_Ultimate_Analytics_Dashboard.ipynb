# %% [markdown]
# # 🎵 MusicScope™ Ultimate Analytics Dashboard\n\n**Data-Science Grade Storytelling with 15 Interactive Charts**\n\n*Generated: 2025-09-17 02:55:59*\n\n## 📋 Chart Inventory (15 Total)\n\n### 🎭 Sentiment Analysis Suite (Charts 1-6)\n1. **Diverging Sentiment Bars** - Wilson CIs\n2. **Sentiment Heatmap** - Bayesian shrinkage\n3. **Positive Theme Lollipops** - Top fan praise\n4. **Negative Theme Lollipops** - Areas for improvement\n5. **Standout Videos Scatter** - LOESS residual analysis\n6. **Tour Compatibility Matrix** - UMAP clustering\n\n### 📹 Content Analysis Suite (Charts 7-11)\n7. **UpSet Feature Intersections** - Better than Venn\n8. **ISRC Balance Bars** - Music vs content\n9. **Content Length Dumbbells** - Short vs long-form\n10. **Content Type Dots** - MV/lyric/visualizer\n11. **Views by Category Areas** - Time series\n\n### 🎯 Strategic Analytics Suite (Charts 12-15)\n12. **Genre Context Heatmap** - TF-IDF analysis\n13. **Roster Rank Bump Chart** - Weekly trends\n14. **Polarity Ridgelines** - Sentiment distributions\n15. **A/B Test Framework** - Uplift curves\n

# %%
# 📦 Core Data Science Stack\nimport pandas as pd\nimport numpy as np\nimport plotly.graph_objects as go\nimport plotly.express as px\nimport warnings\nwarnings.filterwarnings('ignore')\n\n# 🎨 MusicScope™ Advanced Charts\nfrom youtubeviz.advanced_charts import (\n    create_diverging_sentiment_bars,\n    create_sentiment_cluster_heatmap,\n    create_positive_theme_lollipops,\n    create_negative_theme_lollipops,\n    create_standout_videos_scatter,\n    create_tour_compatibility_analysis,\n    create_upset_feature_intersections,\n    create_isrc_balance_bars,\n    create_content_length_dumbbells,\n    create_content_type_dots,\n    create_views_by_category_areas,\n    create_genre_context_heatmap,\n    create_roster_rank_bump_chart,\n    create_polarity_ridgelines,\n    create_ab_test_framework,\n    enhance_chart_beauty,\n    ColorBrewerPalettes\n)\n\n# 📊 Statistical Foundation\nfrom youtubeviz.statistical_utils import (\n    calculate_wilson_intervals,\n    apply_bayesian_shrinkage,\n    apply_loess_smoothing\n)\n\n# 🎯 Core Analytics\nfrom youtubeviz.data import load_recent_window_days\nfrom youtubeviz.config_validation import get_artists_from_env\n\nprint('✅ All 15 chart functions imported successfully!')\n

# %%
# 🎯 Load Recent Data\nANALYSIS_WINDOW_DAYS = 30\n\ndf = load_recent_window_days(ANALYSIS_WINDOW_DAYS)\nexpected_artists = get_artists_from_env()\n\nprint(f'📊 Loaded {len(df):,} records for {len(df["artist_name"].unique())} artists')\n\n# Add derived columns\ndf['log_views'] = np.log10(df['daily_views'].clip(lower=1))\ndf['has_isrc'] = df.get('isrc', '').notna()\ndf['is_short_form'] = df.get('duration_seconds', 300) < 60\n\nprint('✅ Data preparation complete!')\n

# %% [markdown]
# ## Chart 1: Sentiment Breakdown by Artist\n

# %%
# 📊 Chart 1: Sentiment Breakdown by Artist\ntry:\n    print(f'🎨 Generating Chart 1...')\n    fig_1 = create_diverging_sentiment_bars(df)\n    fig_1 = enhance_chart_beauty(fig_1, theme='professional')\n    fig_1.show()\n    print(f'✅ Chart 1 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 1 issue: {e}')\n    fig_1 = go.Figure()\n    fig_1.add_annotation(text=f'Chart 1: {e}', x=0.5, y=0.5)\n    fig_1.update_layout(title='Chart 1: Sentiment Breakdown by Artist', height=300)\n    fig_1.show()\n

# %% [markdown]
# ## Chart 2: Sentiment Model Categories Heatmap\n

# %%
# 📊 Chart 2: Sentiment Model Categories Heatmap\ntry:\n    print(f'🎨 Generating Chart 2...')\n    fig_2 = create_sentiment_cluster_heatmap(df)\n    fig_2 = enhance_chart_beauty(fig_2, theme='professional')\n    fig_2.show()\n    print(f'✅ Chart 2 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 2 issue: {e}')\n    fig_2 = go.Figure()\n    fig_2.add_annotation(text=f'Chart 2: {e}', x=0.5, y=0.5)\n    fig_2.update_layout(title='Chart 2: Sentiment Model Categories Heatmap', height=300)\n    fig_2.show()\n

# %% [markdown]
# ## Chart 3: Top 3 Positive Themes per Artist\n

# %%
# 📊 Chart 3: Top 3 Positive Themes per Artist\ntry:\n    print(f'🎨 Generating Chart 3...')\n    fig_3 = create_positive_theme_lollipops(df)\n    fig_3 = enhance_chart_beauty(fig_3, theme='professional')\n    fig_3.show()\n    print(f'✅ Chart 3 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 3 issue: {e}')\n    fig_3 = go.Figure()\n    fig_3.add_annotation(text=f'Chart 3: {e}', x=0.5, y=0.5)\n    fig_3.update_layout(title='Chart 3: Top 3 Positive Themes per Artist', height=300)\n    fig_3.show()\n

# %% [markdown]
# ## Chart 4: Top 3 Negative Themes per Artist\n

# %%
# 📊 Chart 4: Top 3 Negative Themes per Artist\ntry:\n    print(f'🎨 Generating Chart 4...')\n    fig_4 = create_negative_theme_lollipops(df)\n    fig_4 = enhance_chart_beauty(fig_4, theme='professional')\n    fig_4.show()\n    print(f'✅ Chart 4 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 4 issue: {e}')\n    fig_4 = go.Figure()\n    fig_4.add_annotation(text=f'Chart 4: {e}', x=0.5, y=0.5)\n    fig_4.update_layout(title='Chart 4: Top 3 Negative Themes per Artist', height=300)\n    fig_4.show()\n

# %% [markdown]
# ## Chart 5: Standout Videos Analysis\n

# %%
# 📊 Chart 5: Standout Videos Analysis\ntry:\n    print(f'🎨 Generating Chart 5...')\n    fig_5 = create_standout_videos_scatter(df)\n    fig_5 = enhance_chart_beauty(fig_5, theme='professional')\n    fig_5.show()\n    print(f'✅ Chart 5 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 5 issue: {e}')\n    fig_5 = go.Figure()\n    fig_5.add_annotation(text=f'Chart 5: {e}', x=0.5, y=0.5)\n    fig_5.update_layout(title='Chart 5: Standout Videos Analysis', height=300)\n    fig_5.show()\n

# %% [markdown]
# ## Chart 6: Tour Compatibility Analysis\n

# %%
# 📊 Chart 6: Tour Compatibility Analysis\ntry:\n    print(f'🎨 Generating Chart 6...')\n    fig_6 = create_tour_compatibility_analysis(df)\n    fig_6 = enhance_chart_beauty(fig_6, theme='professional')\n    fig_6.show()\n    print(f'✅ Chart 6 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 6 issue: {e}')\n    fig_6 = go.Figure()\n    fig_6.add_annotation(text=f'Chart 6: {e}', x=0.5, y=0.5)\n    fig_6.update_layout(title='Chart 6: Tour Compatibility Analysis', height=300)\n    fig_6.show()\n

# %% [markdown]
# ## Chart 7: Feature Intersection Analysis\n

# %%
# 📊 Chart 7: Feature Intersection Analysis\ntry:\n    print(f'🎨 Generating Chart 7...')\n    fig_7 = create_upset_feature_intersections(df)\n    fig_7 = enhance_chart_beauty(fig_7, theme='professional')\n    fig_7.show()\n    print(f'✅ Chart 7 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 7 issue: {e}')\n    fig_7 = go.Figure()\n    fig_7.add_annotation(text=f'Chart 7: {e}', x=0.5, y=0.5)\n    fig_7.update_layout(title='Chart 7: Feature Intersection Analysis', height=300)\n    fig_7.show()\n

# %% [markdown]
# ## Chart 8: ISRC vs Non-ISRC Balance\n

# %%
# 📊 Chart 8: ISRC vs Non-ISRC Balance\ntry:\n    print(f'🎨 Generating Chart 8...')\n    fig_8 = create_isrc_balance_bars(df)\n    fig_8 = enhance_chart_beauty(fig_8, theme='professional')\n    fig_8.show()\n    print(f'✅ Chart 8 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 8 issue: {e}')\n    fig_8 = go.Figure()\n    fig_8.add_annotation(text=f'Chart 8: {e}', x=0.5, y=0.5)\n    fig_8.update_layout(title='Chart 8: ISRC vs Non-ISRC Balance', height=300)\n    fig_8.show()\n

# %% [markdown]
# ## Chart 9: Content Length Analysis\n

# %%
# 📊 Chart 9: Content Length Analysis\ntry:\n    print(f'🎨 Generating Chart 9...')\n    fig_9 = create_content_length_dumbbells(df)\n    fig_9 = enhance_chart_beauty(fig_9, theme='professional')\n    fig_9.show()\n    print(f'✅ Chart 9 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 9 issue: {e}')\n    fig_9 = go.Figure()\n    fig_9.add_annotation(text=f'Chart 9: {e}', x=0.5, y=0.5)\n    fig_9.update_layout(title='Chart 9: Content Length Analysis', height=300)\n    fig_9.show()\n

# %% [markdown]
# ## Chart 10: Content Type Breakdown\n

# %%
# 📊 Chart 10: Content Type Breakdown\ntry:\n    print(f'🎨 Generating Chart 10...')\n    fig_10 = create_content_type_dots(df)\n    fig_10 = enhance_chart_beauty(fig_10, theme='professional')\n    fig_10.show()\n    print(f'✅ Chart 10 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 10 issue: {e}')\n    fig_10 = go.Figure()\n    fig_10.add_annotation(text=f'Chart 10: {e}', x=0.5, y=0.5)\n    fig_10.update_layout(title='Chart 10: Content Type Breakdown', height=300)\n    fig_10.show()\n

# %% [markdown]
# ## Chart 11: Views by Category Over Time\n

# %%
# 📊 Chart 11: Views by Category Over Time\ntry:\n    print(f'🎨 Generating Chart 11...')\n    fig_11 = create_views_by_category_areas(df)\n    fig_11 = enhance_chart_beauty(fig_11, theme='professional')\n    fig_11.show()\n    print(f'✅ Chart 11 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 11 issue: {e}')\n    fig_11 = go.Figure()\n    fig_11.add_annotation(text=f'Chart 11: {e}', x=0.5, y=0.5)\n    fig_11.update_layout(title='Chart 11: Views by Category Over Time', height=300)\n    fig_11.show()\n

# %% [markdown]
# ## Chart 12: Genre Context Analysis\n

# %%
# 📊 Chart 12: Genre Context Analysis\ntry:\n    print(f'🎨 Generating Chart 12...')\n    fig_12 = create_genre_context_heatmap(df)\n    fig_12 = enhance_chart_beauty(fig_12, theme='professional')\n    fig_12.show()\n    print(f'✅ Chart 12 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 12 issue: {e}')\n    fig_12 = go.Figure()\n    fig_12.add_annotation(text=f'Chart 12: {e}', x=0.5, y=0.5)\n    fig_12.update_layout(title='Chart 12: Genre Context Analysis', height=300)\n    fig_12.show()\n

# %% [markdown]
# ## Chart 13: Roster Ranking Over Time\n

# %%
# 📊 Chart 13: Roster Ranking Over Time\ntry:\n    print(f'🎨 Generating Chart 13...')\n    fig_13 = create_roster_rank_bump_chart(df)\n    fig_13 = enhance_chart_beauty(fig_13, theme='professional')\n    fig_13.show()\n    print(f'✅ Chart 13 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 13 issue: {e}')\n    fig_13 = go.Figure()\n    fig_13.add_annotation(text=f'Chart 13: {e}', x=0.5, y=0.5)\n    fig_13.update_layout(title='Chart 13: Roster Ranking Over Time', height=300)\n    fig_13.show()\n

# %% [markdown]
# ## Chart 14: Comment Polarity Distributions\n

# %%
# 📊 Chart 14: Comment Polarity Distributions\ntry:\n    print(f'🎨 Generating Chart 14...')\n    fig_14 = create_polarity_ridgelines(df)\n    fig_14 = enhance_chart_beauty(fig_14, theme='professional')\n    fig_14.show()\n    print(f'✅ Chart 14 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 14 issue: {e}')\n    fig_14 = go.Figure()\n    fig_14.add_annotation(text=f'Chart 14: {e}', x=0.5, y=0.5)\n    fig_14.update_layout(title='Chart 14: Comment Polarity Distributions', height=300)\n    fig_14.show()\n

# %% [markdown]
# ## Chart 15: A/B Test Framework\n

# %%
# 📊 Chart 15: A/B Test Framework\ntry:\n    print(f'🎨 Generating Chart 15...')\n    fig_15 = create_ab_test_framework(df)\n    fig_15 = enhance_chart_beauty(fig_15, theme='professional')\n    fig_15.show()\n    print(f'✅ Chart 15 complete')\nexcept Exception as e:\n    print(f'⚠️  Chart 15 issue: {e}')\n    fig_15 = go.Figure()\n    fig_15.add_annotation(text=f'Chart 15: {e}', x=0.5, y=0.5)\n    fig_15.update_layout(title='Chart 15: A/B Test Framework', height=300)\n    fig_15.show()\n

# %% [markdown]
# ## 🎯 Final Validation\n

# %%
# 🎯 Count All Charts\nchart_figures = []\nfor i in range(1, 16):\n    fig_name = f'fig_{i}'\n    if fig_name in locals():\n        chart_figures.append(fig_name)\n\nprint(f'📊 FINAL CHART COUNT: {len(chart_figures)}/15')\n\nif len(chart_figures) == 15:\n    print('🎉 SUCCESS: All 15 data-science-grade charts completed!')\nelse:\n    print(f'⚠️  Missing {15 - len(chart_figures)} charts')\n\nprint('🎵 MusicScope™ Ultimate Analytics Dashboard Complete! 🎵')\n
