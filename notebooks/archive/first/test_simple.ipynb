# %%
# Simple test
print('Hello from notebook!')
x = 2 + 2
print(f'2 + 2 = {x}')

# %%
# Test plotly
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=[1, 2, 3], y=[4, 5, 6]))
fig.update_layout(title='Test Chart')
fig.show()
print('Chart should appear above')
