# %% [markdown]
# # 🎤 Artist Comparison — Who deserves extra budget?
#
# Benchmark momentum and engagement across our roster with human narrative next to each chart.

# %%
from youtubeviz.storytelling import story_block, quick_takeaways
from youtubeviz.charts import views_over_time_advanced
# from youtubeviz.data import load_recent_window_days  # enable when DB is configured

# Example scaffold (kept light so it doesn't require DB to import):
# ARTISTS = ["Flyana Boss", "COBRAH", "Raiche"]
# df = load_recent_window_days(artists=ARTISTS, days=60)
# fig = views_over_time_advanced(df, 'date', 'views', 'artist_name', rolling_window=7, highlight_artists=[ARTISTS[0]])
# bullets = quick_takeaways(artist=ARTISTS[0], last_7d_change_pct=24.1, engagement_rate=4.9, standout_video="Breakout Track")
# story_block(fig, title="🔥 Standout performer this month", bullets=bullets, caption="Action: allocate promo budget + playlist push")
