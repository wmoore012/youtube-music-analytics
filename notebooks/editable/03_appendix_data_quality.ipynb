# %% [markdown]
# # 🔍 Data Quality Appendix — Bot Detection & Integrity Checks
#
# This appendix documents our bot detection configuration and high-level integrity checks to ensure trust in analytics.

# %%
# Bot detection imports (presence validated by tests)
from src.youtubeviz.bot_detection import (
    BotDetectionConfig,
    BotDetector,
    analyze_bot_patterns,
)

print('✅ Bot detection modules imported: BotDetectionConfig, BotDetector, analyze_bot_patterns')

# %% [markdown]
# ## 🔬 Methodology Snapshot
#
# We analyze duplicate clusters, burst activity, and near-duplicate comments to flag inorganic engagement.
# Configuration lives in `.env` and is wired via `BotDetectionConfig`.

# %%
# Example usage (kept safe and non-executing without DB context)
# from web.etl_helpers import get_engine
# engine = get_engine()
# config = BotDetectionConfig()
# results = analyze_bot_patterns(engine, config=config, days=30)
# print(results.head())  # bot_detection results preview
pass
