# %% [markdown]
# # 🎶 Music-Focused Analytics — Portfolio Overview
#
# Descriptive, prescriptive, and predictive insights with fun, human narrative.

# %%
from youtubeviz.storytelling import story_block, quick_takeaways
from youtubeviz.charts import views_over_time_advanced
# from youtubeviz.data import load_recent_window_days  # enable when DB is configured

# Example scaffold (kept light so it doesn't require DB to import):
# ARTISTS = ["Flyana Boss", "COBRAH", "Raiche"]
# df = load_recent_window_days(artists=ARTISTS, days=90)
# fig = views_over_time_advanced(df, 'date', 'views', 'artist_name', rolling_window=7, highlight_artists=[ARTISTS[0]])
# bullets = quick_takeaways(artist=ARTISTS[0], last_7d_change_pct=32.4, engagement_rate=5.8, standout_video="You Wish")
# story_block(fig, title="🚀 Momentum building in the last 7 days", bullets=bullets, caption="Recommendation: boost Shorts + collab outreach")
